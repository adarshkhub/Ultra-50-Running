# %%
#Combine first and last name
#Create total minutes
#Rename division to gender
#Need to put city state in lat long

# !pip install geopy
# Out:
# ...
#   Obtaining dependency information for geopy from https://files.pythonhosted.org/packages/e5/15/cf2a69ade4b194aa524ac75112d5caac37414b20a3a03e6865dfe0bd1539/geopy-2.4.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for geographiclib<3,>=1.52 from https://files.pythonhosted.org/packages/9f/5a/a26132406f1f40cf51ea349a5f11b0a46cec02a2031ff82e391c2537247a/geographiclib-2.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/125.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/125.4 kB ? eta -:--:--
#    ------------ -------------------------- 41.0/125.4 kB 653.6 kB/s eta 0:00:01
#    ---------------------------------------- 125.4/125.4 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/40.3 kB ? eta -:--:--
#    ---------------------------------------- 40.3/40.3 kB 2.0 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
from geopy.extra.rate_limiter import RateLimiter

# %%
U50df = pd.read_csv("C:/Users/adars/Desktop/Practice_Python_Data/Ultra_50_Running.csv")

# %%
U50df.head()
# Out:
#    Place    First     Last              City State  Age Division     Time
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17

# %%
#Combine first and last name
#Create total minutes
#Rename division to gender
#Need to put city state in lat long

U50df["Name"] = U50df["First"] + ' ' + U50df["Last"]

# %%
#Combine first and last name check
U50df.head()
# Out:
#    Place    First     Last              City State  Age Division     Time  \
# 0      1   Daniel   Wilson             Tulsa    OK   35        M  8:23:01
# 1      2     Eric    Davis         Greenwood    IN   38        M  8:57:54
# 2      3  Stewart  Edwards  New Smyrna Beach    FL   43        M  9:24:35
# 3      4      Ron  Hammett         Montverde    FL   53        M  9:24:36
# 4      5     Seth     Cain            Geneva    FL   44        M  9:42:17
#
#               Name
# 0    Daniel Wilson
# 1       Eric Davis
# 2  Stewart Edwards
# 3      Ron Hammett
# 4        Seth Cain

# %%
#Drop the now extraneous First and Last columns

U50df = U50df.drop(["First"], axis = 1)

# %%
U50df = U50df.drop(["Last"], axis = 1)

# %%
U50df.head()
# Out:
#    Place              City State  Age Division     Time             Name
# 0      1             Tulsa    OK   35        M  8:23:01    Daniel Wilson
# 1      2         Greenwood    IN   38        M  8:57:54       Eric Davis
# 2      3  New Smyrna Beach    FL   43        M  9:24:35  Stewart Edwards
# 3      4         Montverde    FL   53        M  9:24:36      Ron Hammett
# 4      5            Geneva    FL   44        M  9:42:17        Seth Cain

# %%
U50df["Time"] = pd.to_timedelta(U50df["Time"])

# %%
U50df["Total_Minutes"] = U50df["Time"].dt.total_seconds()/60

# %%
U50df["Total_Minutes"] = U50df["Total_Minutes"].round().astype(int)

# %%
U50df.rename(columns = {"Division" : "Gender"}, inplace = True)

# %%
U50df.head()
# Out:
#    Place              City State  Age Gender            Time             Name  \
# 0      1             Tulsa    OK   35      M 0 days 08:23:01    Daniel Wilson
# 1      2         Greenwood    IN   38      M 0 days 08:57:54       Eric Davis
# 2      3  New Smyrna Beach    FL   43      M 0 days 09:24:35  Stewart Edwards
# 3      4         Montverde    FL   53      M 0 days 09:24:36      Ron Hammett
# 4      5            Geneva    FL   44      M 0 days 09:42:17        Seth Cain
#
#    Total_Minutes
# 0            503
# 1            538
# 2            565
# 3            565
# 4            582

# %%
# Put City and State into Lat_Long coordinates
